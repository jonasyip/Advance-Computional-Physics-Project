# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
time_taken = [0.00031495094299316406, 3.886222839355469e-05, 3.504753112792969e-05, 2.9087066650390625e-05, 3.4809112548828125e-05, 3.814697265625e-05, 5.507469177246094e-05, 0.00010991096496582031, 0.00018405914306640625, 0.00040793418884277344, 0.0008678436279296875, 0.0018758773803710938, 0.0038340091705322266, 0.008148193359375, 0.015901803970336914, 0.029776811599731445, 0.05198407173156738]

# %%
plt.title("Counting primes")
plt.loglog(n, time_taken, alpha=0.5)
plt.scatter(n, time_taken)
plt.ylabel("Time taken (seconds)")
plt.xlabel("Numbers counted")
plt.show()
