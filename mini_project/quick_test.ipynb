# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as random
import pandas as pd

# %%
#Mass distribution

N_size = 1000

mass_list = random.gamma(6, 1, N_size)
count, bins, ignored = plt.hist(mass_list, 50, density = True)
plt.show()

# %%
print(random.normal(loc=0.0, scale=1000.0, size=100))
# Out:
# [  849.00883433   346.3881517    300.42093187   397.80778995
#     50.71467265  -599.85003277  1501.35385489    91.28961297
#   2515.52757946   916.09065053 -1454.75807159  1734.75432204
#   1221.13687487   506.8017217  -1021.3350062   -141.27248109
#   -502.56337146 -1260.95718051 -1770.49400023 -1907.53290027
#   1823.02103852  1334.50026028   830.80261087   791.54510346
#    135.51856433   351.99597349 -1072.2657272    -80.66411632
#   1483.00177586  -963.14304078   261.98689737   416.58519087
#    333.40906807  -240.46862769 -1006.0800517   -275.47882826
#     94.40755477    16.99642114 -1496.92691668  -458.39576264
#   -529.58920986  -306.85702123   159.68556441  -647.76930628
#    367.01362104   115.28229033 -1687.59927928   543.94016004
#   -727.04949807 -1171.43392621   -81.16201999  2311.33325344
#   -824.02908559   458.84582456    17.7223577   -191.06679376
#   -744.97983264   871.30430274   437.04529377  1411.37977709
#   1597.15614756    52.49161906   122.92875346  1015.73941971
#   1728.10146819   226.35708417   501.88792668  1692.17768042
#   -368.50716155   966.60079342  1663.11744947 -1477.18394708
#   1082.53957937 -1151.82518859  -586.65348229 -1652.58248607
#   2357.09711711    68.2198062  -1522.90818104 -1185.31945443
#   1494.55756583   439.20602255    84.07328688  1035.8765027
#    508.04478273 -1433.7890681   -596.67086309 -1165.67005311
#   -638.17011829  1078.82640592  -937.94633941 -2460.44360481
#    695.78418296   541.09524528  -940.3197485   -578.87668243
#    841.92481435    81.01277098 -1014.15653416   546.53049897]

# %%
a = np.array([-1, -2, -3])
b = np.array([1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined
